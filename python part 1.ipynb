# %% [markdown]
# ![Presentation1.png](attachment:Presentation1.png)

# %% [markdown]
# #  Print Statement & Comments

# %% [markdown]
# প্রিন্ট () ফাংশন স্ক্রীনে নির্দিষ্ট বার্তা প্রিন্ট করে, বার্তাটি একটি স্ট্রিং হতে পারে, বা অন্য কোন বস্তু হতে পারে, বস্তুটি ্ক্রীন এ লেখার আগে একটি স্ট্রিংয়ে
#
# রূপান্তরিত হবে। এবং কোন কিছু প্রিন্ট করার জন্য শুধু মাত্র print() স্টেইট্মেন্ট ব্যাবহার করলেই হবে।

# %%
print(5)

# %%
print(1000)

# %% [markdown]
# সংখ্যা কে স্ট্রিং এ (' ') or (" ") কোটেশন এর ভিতর রাখা লাগে না , কিন্তু আমরা যদি এখন কোনো বাক্য /লাইন প্রিন্ট করতে চাই তাহলে আমাদের অবশ্যই
#
# লিখাটিকে (' ') or (" ") কোটেশন এর ভিতর রাখা লাগবে

# %% [markdown]
# # যদি কোটেশন এর ভিতর না রাখি তা নিম্নরূপ এরর দিবে

# %%
print (welcome to RAKSHIT.AI PRESENTS BASIC PYTHON COURSE)

# %% [markdown]
# # যদি কোটেশন এর ভিতর রাখি তা নিম্নরূপ ফলাফল দিবে

# %%
print ('welcome to RAKSHIT.AI PRESENTS BASIC PYTHON COURSE')
print ("welcome to RAKSHIT.AI PRESENTS BASIC PYTHON COURSE")

# %% [markdown]
# তাহলে আমরা জানতে পারলাম
#
# (১) কোনো কিছু প্রিন্ট করানোর সময় তা যদি বাক্য বা লাইন হয় তাকে (' ') কোটেশন এর ভিতর রাখা লাগবে
#
# (২ )আর সংখ্যা হলে তাকে শুধুমাত্র () ব্রেকেট এর ভিতর রাখলেই হবে

# %% [markdown]
# PRINT() এর আরো অনেক কাজ আছে এর আগে আমরা প্রোগ্রামিং এর আরেকটি
#
# গুরুত্বপূর্ণ অংশ সম্পর্কে একটু জানি যা হলো ভ্যারিয়েবল
# # VARIABLE

# %%
x = ("welcome to RAKSHIT.AI PRESENTS BASIC PYTHON COURSE")

# %% [markdown]
# ভ্যারিয়েবল এর বাংলা মানে হলো চলক
#
# এখানে x একটি ভ্যারিয়েবল যার ভেতরে আমরা আমাদের বাক্য কে এসাইন করে দিচ্ছি , এর মানে হলো আমাদের এই সম্পূর্ণ লাইন বার বার লিখে প্রিন্ট
#
# করানোর দরকার নেই  আমরা এখন যদি শুধু মাত্র x ভারিয়াবলে কে প্রিন্ট করি তাহলে এই সম্পূর্ণ লাইন প্রিন্ট হবে

# %%
print(x)

# %% [markdown]
# # more examples

# %%
y=("hi how are you")
print(y)

# %%
a=("my name is dip")
b=("my name is dipanjal")
c=("my name is rakshit")

# %%
print(a)

# %%
print(b)

# %%
print(c)

# %% [markdown]
# তিনটে ভ্যারিয়েবল কে একসাথে প্রিন্ট করতে চাইলে

# %%
print(a,b,c)

# %% [markdown]
# একই ভাবে আমরা ম্যাথমেটিক্যাল সমস্যা কেও কাজ করতে পারি,
# ধরি
# D = 10
# E = 20
#
# sum = ?

# %%
D= 10
E= 20

sum=D+E
print(sum)


#এখানে ১০এবং 20 নির্ধারিত সংখ্যা কে আমরা দুইটা ভ্যারিয়েবল এ এসাইন  করে দিলাম D & E এ নামে এখন তাদের যোগফল  দেখানোর জন্য sum নামের আরেকটা ভ্যারিয়েবল নিলাম এবং তাতে আগের কে অ্যাড করে দিলাম

# %% [markdown]
# # Comments

# %% [markdown]
# কমেন্ট হলো যখন কোড কিছু মনে রাখার জন্য অথবা সুবিধার জন্য নোট করে রাখা হয় এবং এবং সেই লাইন গুলো কোড এ এক্সেকিউতে হবে না
# দুই ভাবে এদের প্রকাশ করা যাই
# <ol>
# <li>#</li>
# <li>''' ''''</li>
#
# </ol>

# %%
# this is a single line comment 
# if i use enter for another line again i have to use # sign 

'''
this is a multiple line comment i can use enter here 
after using the enter it still goes as comment'''

# %% [markdown]
# # Hope you like it .for any querry dipanjalrakshit1@gmail.com
